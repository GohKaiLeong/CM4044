# %% [markdown]
# ## Matplotlib Exercise
#
# For this exercise, we are using Matplotlib to visualize Company Sales Data, which is stored in a text file, "company_sales_data.csv". It is available in NTULearn.
#
# The data file has 9 columns of data with a header for every column's name:
#
# "month_number","facecream","facewash","toothpaste","bathingsoap","shampoo","moisturizer","total_units","total_profit"

# %% [markdown]
# ### 1.
# Read total profit of all months from "company_sales_data.csv" and show it using a line plot:
#
# Total profit data provided for each month. Generated line plot must include the following properties: –
#
# - X label name = Month
# - Y label name = Total profit
# - figure title: Company profit per month
# - x ticks: month number
# - y ticks: 100000, 200000, 300000, 400000, 500000
#
# Solution:

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline    
import pandas as pd

profits = pd.read_csv("company_sales_data.csv")
profits
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
# ...

# %%
# plt method
plt.figure(figsize=(7,5),dpi=100)

X=profits['month_number']
Y=profits['total_profit']

plt.plot(X, Y)

plt.title('Company profit per month')
plt.xlabel('Month')
plt.ylabel('Total profit')

plt.xticks(X)
plt.yticks([100000, 200000, 300000, 400000, 500000])

plt.show()

# %%
# OOP method
fig = plt.figure(figsize=(7,5), dpi=100)

X=profits['month_number']
Y=profits['total_profit']

ax = fig.add_axes([0.1, 0.1, 0.8, 0.8])
ax.plot(X,Y)

ax.set_title('Company profit per month')
ax.set_xlabel('Month')
ax.set_ylabel('Total profit')

ax.set_xticks(X)
ax.set_yticks([100000, 200000, 300000, 400000, 500000])

plt.show()

# %% [markdown]
# ### 2.
#
# Generated line plot for company profit data to include following Style properties:
#
# - Line Style dotted and Line-color should be red
# - Show legend at the lower right location. Legent text: Profit data of last year
# - X label name = Month
# - Y label name = Total profit
# - Add a circle marker.
# - Line marker color as read
# - Line width should be 3
#
# Solution:

# %%
# plt method
plt.figure(figsize=(7,5),dpi=100)

X=profits['month_number']
Y=profits['total_profit']

plt.plot(X, Y, color='red', linewidth=3, linestyle=":") # Line Style dotted and Line-color should be red, line width = 3

plt.legend(['Profit data of last year'], loc="lower right")  
plt.xlabel('Month')
plt.ylabel('Total profit')

plt.scatter(X, Y, 50, color='red') # add red circle

plt.title('Company profit per month')
plt.xticks(X)
plt.yticks([100000, 200000, 300000, 400000, 500000])

plt.show()

# %%
# OOP method
fig = plt.figure(figsize=(7,5), dpi=100)

X=profits['month_number']
Y=profits['total_profit']

ax = fig.add_axes([0.1, 0.1, 0.8, 0.8])
ax.plot(X,Y,color ='red', linewidth=3, linestyle=":")

ax.legend(['Profit data of last year'], loc="lower right")  
ax.set_xlabel('Month')
ax.set_ylabel('Total profit')

ax.scatter(X, Y, 50, color='red')

ax.set_title('Company profit per month')
ax.set_xticks(X)
ax.set_yticks([100000, 200000, 300000, 400000, 500000])

plt.show()

# %% [markdown]
# ### 3.
#
# Read all product sales data and show it using a multiline plot:
#
# Display the number of units sold per month for each product using multiline plots. (i.e., separate Plotline for each product for each product).
#
# - every line has different colour
# - linewidth 3
# - use cicle as data marker
# - show the legend on the upper left corner of the plot
# - legend text "xxxx Sales Data", xxxx is the goods item name, such as face cream, Toothpaste, etc.
# - x label "Month"
# - y label "Sales units in number"
# - figure title "Sales data"
# - xticks: month number
# - yticks: 1000, 2000, 4000, 6000, 8000, 10000, 12000, 15000, 18000
#
# Solution:

# %%
# plt method
plt.figure(figsize=(7,5),dpi=100)

X=profits['month_number']
Y1=profits['facecream']
Y2=profits['facewash']
Y3=profits['toothpaste']
Y4=profits['bathingsoap']
Y5=profits['shampoo']
Y6=profits['moisturizer']

plt.title('Sales data')
plt.xlabel('Month')
plt.ylabel('Sales units in number')

plt.plot(X, Y1, color='red', linewidth=3) 
plt.plot(X, Y2, color='cyan', linewidth=3) 
plt.plot(X, Y3, color='orange', linewidth=3) 
plt.plot(X, Y4, color='green', linewidth=3) 
plt.plot(X, Y5, color='blue', linewidth=3) 
plt.plot(X, Y6, color='purple', linewidth=3) 

plt.scatter(X, Y1, 50, color='red')
plt.scatter(X, Y2, 100, color='cyan')
plt.scatter(X, Y3, 50, color='orange')
plt.scatter(X, Y4, 50, color='green')
plt.scatter(X, Y5, 50, color='blue')
plt.scatter(X, Y6, 30, color='purple')

labels = ['Face cream sales data', 'Face wash sales data', 'Toothpaste sales data', 'Bathing soap sales data', 'Shampoo sales data', 'Moisturizer sales data']
plt.legend(labels, loc="upper left")  

plt.xticks(X)
plt.yticks([1000, 2000, 4000, 6000, 8000, 10000, 12000, 15000, 18000])

plt.show()

# %%
# OOP method
fig = plt.figure(figsize=(7,5),dpi=100)
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8])

X=profits['month_number']
Y1=profits['facecream']
Y2=profits['facewash']
Y3=profits['toothpaste']
Y4=profits['bathingsoap']
Y5=profits['shampoo']
Y6=profits['moisturizer']

ax.set_title('Sales data')
ax.set_xlabel('Month')
ax.set_ylabel('Sales units in number')

ax.plot(X, Y1, color='red', linewidth=3) 
ax.plot(X, Y2, color='cyan', linewidth=3) 
ax.plot(X, Y3, color='orange', linewidth=3) 
ax.plot(X, Y4, color='green', linewidth=3) 
ax.plot(X, Y5, color='blue', linewidth=3) 
ax.plot(X, Y6, color='purple', linewidth=3) 

ax.scatter(X, Y1, 50, color='red')
ax.scatter(X, Y2, 100, color='cyan')
ax.scatter(X, Y3, 50, color='orange')
ax.scatter(X, Y4, 50, color='green')
ax.scatter(X, Y5, 50, color='blue')
ax.scatter(X, Y6, 30, color='purple')

labels = ['Face cream sales data', 'Face wash sales data', 'Toothpaste sales data', 'Bathing soap sales data', 'Shampoo sales data', 'Moisturizer sales data']
ax.legend(labels, loc="upper left")  

ax.set_xticks(X)
ax.set_yticks([1000, 2000, 4000, 6000, 8000, 10000, 12000, 15000, 18000])

plt.show()

# %% [markdown]
# ### 4.
#
# Read toothpaste sales data of each month and show it using a scatter plot. Add a grid in the plot and Gridline style should “–“.
#
# - scatter point in purple colour
# - use cicle as data marker
# - show the legend on the upper left corner of the plot
# - legend text "Tooth paste Sales Data"
# - x label "Month"
# - y label "Sales units in number"
# - figure title "Tooth paste Sales data"
# - xticks: month number
# - yticks: use system default value
#
# Solution:

# %%
# plt method
plt.figure(figsize=(7,5),dpi=100)

X=profits['month_number']
Y=profits['toothpaste']

plt.grid(linestyle="-")
plt.scatter(X, Y, 50, color='purple')
plt.xlabel('Month')
plt.ylabel('Sales units in number')
plt.title('Tooth paste Sales data')
plt.legend(['Tooth paste Sales Data'], loc="upper left")  

plt.xticks(X)

plt.show()

# %%
# OOP method
fig = plt.figure(figsize=(7,5),dpi=100)
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8])

X=profits['month_number']
Y=profits['toothpaste']

ax.grid(linestyle="-")
ax.scatter(X, Y, 50, color='purple')
ax.set_title('Tooth paste Sales data')
ax.set_xlabel('Month')
ax.set_ylabel('Sales units in number')
ax.legend(['Tooth paste Sales Data'], loc="upper left")  

ax.set_xticks(X)

plt.show()

# %% [markdown]
# ### 5.
#
# Read face cream and face wash product sales data and show it using the bar chart. Bar chart should display the number of units sold per month for each product. Add a separate bar for each product in the same chart.
#
# - legend text: "Face Cream Sales Data" and "Face Wash Sales Data"
# - legend position well so that legend will not overlap with bars in the plot
# - x label "Month"
# - y label "Sales units in number"
# - figure title "Facewash and FaceCream Sales Data"
# - xticks: month
# - yticks: use system default value
#
# Solution:

# %%
# plt method
plt.figure(figsize=(12,5),dpi=100)

X=profits['month_number']
Y1=profits['facecream']
Y2=profits['facewash']

plt.title('Facewash and FaceCream Sales Data')
plt.xlabel('Month')
plt.ylabel('Sales units in number')

rects1 = plt.bar(X-0.21, Y1, 0.4, color='red', label = 'Face Cream Sales Data') 
rects2 = plt.bar(X+0.21, Y2, 0.4, color='orange', label = 'Face Wash Sales Data')

def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        plt.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 0),  
                    textcoords="offset points",
                    ha='center', va='bottom')
            
autolabel(rects1)
autolabel(rects2)

plt.legend(loc="best", fontsize=8)  

plt.xticks(X)

plt.show()

# %%
# OOP method
fig = plt.figure(figsize=(12,5),dpi=100)
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8])

X=profits['month_number']
Y1=profits['facecream']
Y2=profits['facewash']

ax.set_title('Facewash and FaceCream Sales Data')
ax.set_xlabel('Month')
ax.set_ylabel('Sales units in number')

rects1 = ax.bar(X-0.21, Y1, 0.4, color='red', label = 'Face Cream Sales Data') 
rects2 = ax.bar(X+0.21, Y2, 0.4, color='orange', label = 'Face Wash Sales Data')

def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 0),
                    textcoords="offset points",
                    ha='center', va='bottom')
            
autolabel(rects1)
autolabel(rects2)

ax.legend(loc="best", fontsize=8)  

ax.set_xticks(X)

plt.show()

# %% [markdown]
# ### 6.
#
# Read the total profit of each month and show it using the histogram to see most common profit ranges
#
# - The bins: 150000, 175000, 200000, 225000, 250000, 300000, 350000
# - x label : Profit range in dollar
# - y label : Actual Profit in dolar
# - legend on the best corner
# - title: Profit data
#
# Solution:

# %%
# plt method
plt.figure(figsize=(7,5),dpi=100)

X=profits['total_profit']

plt.hist(X, bins=[150000, 175000, 200000, 225000, 250000, 300000, 350000])

plt.title('Profit Data')
plt.xlabel('Profit range in dollar')
plt.ylabel('Actual Profit in dollar')

plt.legend(["Actual profit"], loc="best")  

plt.show()

# %%
# OOP method
fig = plt.figure(figsize=(7,5),dpi=100)
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8])

X=profits['total_profit']

ax.hist(X, bins=[150000, 175000, 200000, 225000, 250000, 300000, 350000])

ax.set_title('Profit Data')
ax.set_xlabel('Profit range in dollar')
ax.set_ylabel('Actual Profit in dollar')

ax.legend(["Actual profit"], loc="best")  

plt.show()

# %% [markdown]
# ### 7.
#
# Use subplots to display sales data for Bathingsoap, Facewash, Facecream and Toothpaste.
#
# Solution:

# %%
fig, axes = plt.subplots(2,2, figsize=(8,8))
fig.tight_layout()
axes = axes.flatten()

x = profits["month_number"]

y0 = profits["bathingsoap"] 
axes[0].plot(x, y0, color ='r') 
axes[0].set_title('Bathing soap sales') 
axes[0].set_xticks(x)
axes[0].set_xlabel('Month')
axes[0].set_ylabel('Sales units')
  
y1 = profits["facewash"] 
axes[1].plot(x, y1, color ='b') 
axes[1].set_title('Face wash sales') 
axes[1].set_xticks(x)
axes[1].set_xlabel('Month')
axes[1].set_ylabel('Sales units')
  
y2 = profits["facecream"] 
axes[2].plot(x, y2, color ='g') 
axes[2].set_title('Face cream sales') 
axes[2].set_xticks(x)
axes[2].set_xlabel('Month')
axes[2].set_ylabel('Sales units')
  
y3 = profits["toothpaste"] 
axes[3].plot(x, y3, color ='k') 
axes[3].set_title('Toothpaste sales')
axes[3].set_xticks(x)
axes[3].set_xlabel('Month')
axes[3].set_ylabel('Sales units')
  
fig.subplots_adjust(hspace=.5,wspace=0.5) 

plt.show()

# %% [markdown]
# ### 8.
#
# Read all product sales data and show them using the stack plot.
#
# - legend is on best position, so that it doesn't overlap with plot
# - different colours are used for different product
# - Figure Title: All product sales data in stack plot
# - x title: Month
# - y title: Sales units in number
#
# Solution:

# %%
fig = plt.figure(figsize=(7,5),dpi=100)
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8])

x = profits["month_number"]

y0 = profits["facecream"] 
y1 = profits["facewash"] 
y2 = profits["toothpaste"] 
y3 = profits["bathingsoap"] 
y4 = profits["shampoo"]
y5 = profits["moisturizer"]

legends = ["Face cream", "Face wash", "Toothpaste", "Bathing soap", "Shampoo", "Moisturizer"]
ax.stackplot(x, y0, y1, y2, y3, y4, y5, labels=legends)
ax.set_title("All product sales data in stack plot")
ax.set_xlabel("Month")
ax.set_ylabel("Sales units in number")
ax.set_xticks(x)
ax.legend(loc = "upper left", fontsize=8)

plt.show()
